# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
integ_dir1=0
with open("bubble_data_lh20_nu_0.0ee.npy", 'rb') as f:
            integ_dir1=np.load(f)
integ_dir12=0
with open("bubble_data_20_nu_0.0ee.npy", 'rb') as f:
            integ_dir12=np.load(f)
integ_dir13=0
with open("bubble_data_FG20_nu_0.0ee.npy", 'rb') as f:
            integ_dir13=np.load(f)
kx_dir1=0
with open("bubble_data_kx_20_nu_0.0ee.npy", 'rb') as f:
            kx_dir1=np.load(f)

ky_dir1=0
with open("bubble_data_ky_20_nu_0.0ee.npy", 'rb') as f:
            ky_dir1=np.load(f)

# %%
scatter(kx_dir1,ky_dir1, c=integ_dir1)
colorbar()
show()
scatter(kx_dir1,ky_dir1, c=integ_dir12)
colorbar()
show()
scatter(kx_dir1,ky_dir1, c=integ_dir13)
colorbar()
show()
scatter(kx_dir1,ky_dir1, c=abs(integ_dir12-integ_dir1))
colorbar()
show()
scatter(kx_dir1,ky_dir1, c=abs(integ_dir13-integ_dir1))
colorbar()
show()

ind0=where(ky_dir1==0)
plot(kx_dir1[ind0], integ_dir1[ind0])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
integ_dir2=0
with open("bubble_data_lh22_nu_0.0ee.npy", 'rb') as f:
            integ_dir2=np.load(f)
integ_dir23=0
with open("bubble_data_FG22_nu_0.0ee.npy", 'rb') as f:
            integ_dir23=np.load(f)

integ_dir22=0
with open("bubble_data_22_nu_0.0ee.npy", 'rb') as f:
            integ_dir22=np.load(f)


kx_dir2=0
with open("bubble_data_kx_22_nu_0.0ee.npy", 'rb') as f:
            kx_dir2=np.load(f)

ky_dir2=0
with open("bubble_data_ky_22_nu_0.0ee.npy", 'rb') as f:
            ky_dir2=np.load(f)

# %%
scatter(kx_dir2,ky_dir2, c=integ_dir2)
colorbar()
show()
scatter(kx_dir2,ky_dir2, c=integ_dir22)
colorbar()
show()
scatter(kx_dir2,ky_dir2, c=integ_dir23)
colorbar()
show()
scatter(kx_dir2,ky_dir2, c=abs(integ_dir22-integ_dir2))
colorbar()
show()


scatter(kx_dir2,ky_dir2, c=abs(integ_dir23-integ_dir2))
colorbar()
show()
ind0=where(ky_dir2==0)
plot(kx_dir2[ind0], integ_dir2[ind0])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
integ_moi=0
with open("bubble_data_lh21_nu_0.0ee.npy", 'rb') as f:
            integ_moi=np.load(f)
integ_moi2=0
with open("bubble_data_21_nu_0.0ee.npy", 'rb') as f:
            integ_moi2=np.load(f)
integ_moi3=0
with open("bubble_data_FG21_nu_0.0ee.npy", 'rb') as f:
            integ_moi3=np.load(f)

kx_moi=0
with open("bubble_data_kx_21_nu_0.0ee.npy", 'rb') as f:
            kx_moi=np.load(f)

ky_moi=0
with open("bubble_data_ky_21_nu_0.0ee.npy", 'rb') as f:
            ky_moi=np.load(f)

# %%
scatter(kx_moi,ky_moi, c=integ_moi)
colorbar()
show()
scatter(kx_moi,ky_moi, c=integ_moi2)
colorbar()
show()
scatter(kx_moi,ky_moi, c=integ_moi3)
colorbar()
show()
scatter(kx_moi,ky_moi, c=abs(integ_moi-integ_moi2))
colorbar()
show()
scatter(kx_moi,ky_moi, c=abs(integ_moi3-integ_moi))
colorbar()
show()
ind0=where(ky_moi==0)
plot(kx_moi[ind0], integ_moi[ind0])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
