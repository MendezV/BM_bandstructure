# %%
# %pylab inline
import numpy as np
import pandas as pd
import os
import Hamiltonian
import MoireLattice
from scipy import linalg as la
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
# path=path+'noFFpost_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
path=path+'data20_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=np.real(df_prime['bub']*ev_Ambz))
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)
scatter(df_one_temp['ky'],np.real(df_one_temp['bub']*ev_Ambz))
plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009234189987182617  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
# path=path+'Dir_noPH_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'Dir_noFF_data40_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'Dens_PHfalse_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
path=path+'Den_PHtrue_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()
Vol=l.VolMBZ
print('ASDFASDF',l.LM()*l.GM())
a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=2#/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()

hbvf = (3/(2*np.sqrt(3)))*2.7*q; # eV
df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)
fac=10000/(hbvf*2)
# plot(df_one_temp['ky'],fac*np.abs(df_one_temp['ky']))
plt.show()
print(q)
df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# plot(df_one_temp['kx'],fac*np.abs(df_one_temp['kx']))
plt.show()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009409904479980469  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# ASDFASDF 7.255197456936866
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# 0.07676251561000431
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
scatter(df_prime['kx'],df_prime['ky'],c=df_prime['Em2'])
plt.show()

# %%
# df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
# plt.scatter(df_one_temp['ky'],df_one_temp['Em2'])
# plt.scatter(df_one_temp['ky'],df_one_temp['Em1'])
# print((np.array(df_one_temp['Em1'])[1]-np.array(df_one_temp['Em1'])[0])/(np.array(df_one_temp['ky'])[1]-np.array(df_one_temp['ky'])[0]))
# plt.scatter(df_one_temp['ky'],0.1794913791569725*np.abs(df_one_temp['ky']-1))
# plt.show()
