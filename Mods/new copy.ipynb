# %%
import MoireLattice
import numpy as np
import matplotlib.pyplot as plt

# %%
#Lattice parameters 
#lattices with different normalizations
modulation_theta=1.05
Nsamp=30
theta=modulation_theta*np.pi/180  # magic angle
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0)
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=np.sqrt(q1@q1)
umkl=0
print(f"taking {umkl} umklapps")
VV=lq.boundary()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.03699612617492676  s
# 919 numer of sampling lattice points
# taking 0 umklapps

# %%
plt.scatter(KX, KY)

# %%
[KX,KY]=lq.Generate_lattice_2()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=np.sqrt(q1@q1)
umkl=0
print(f"taking {umkl} umklapps")
VV=lq.boundary()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.010099411010742188  s
# 900 numer of sampling lattice points
# taking 0 umklapps

# %%
plt.scatter(KX, KY)
plt.plot(VV[:,0], VV[:,1], c='r')
