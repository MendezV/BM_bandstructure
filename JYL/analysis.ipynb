# %%
# %pylab inline
import numpy as np
import pandas as pd
import os
import Hamiltonian
import MoireLattice
from scipy import linalg as la
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/jfmv/opt/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['disp', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathMAC
path=pathy+'/Mods/data20_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.8174358974358973_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub'])
colorbar()

# %%
fillings=df['nu']
cep=df['delt_cph']/21400
plt.scatter(fillings, cep, c='b', label='lh')
plt.plot(fillings, cep, c='k', ls='--')
plt.legend()
plt.xlabel(r"$\nu$")
plt.ylabel(r"$\alpha/ c_L$")
# plt.savefig("velocities_V_filling_"+self.name+"_"+str(Nsamp)+"_theta_"+str(theta)+".png")
# Out:
# Text(0, 0.5, '$\\alpha/ c_L$')

# %% [markdown]
# ## For the twist angle 0.75

# %%
kappa=0.75
path=pathy+'/data/thetasweep_kappa_'+str(kappa)+'_T_HR_N30'
subpaths=os.listdir(path)
subpaths=list(filter(lambda a: a != 'inforun', subpaths))

def getdatadir(fulpath,mode):
    data=[]
    for pa in fulpath:
        if ('data' in pa) and (mode in pa): data.append(pa)
    return data
        
thet=[]
renorm=[]
renorm2=[]
frames=[]
tdos=[]
thetass=[]
eners=[]
fils=[]
for i, pat in enumerate(subpaths):
    # print(pat)
    fulpath=path+'/'+pat
    subpaths2=os.listdir(fulpath)
    data= getdatadir(subpaths2, 'T')
    fullpath=fulpath+'/'+data[0]
    
    dff = pd.read_hdf(fullpath)
    frames.append(dff)

    

    Nsamp=100
    theta=dff['theta'][0]
    l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
    lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
    [q1,q2,q3]=l.q
    q=la.norm(q1)
    
    #JY params 
    hbvf = (3/(2*np.sqrt(3)))*2.7; # eV
    hvkd=hbvf*q
    up = 0.105; # eV
    u = kappa*up; # eV
    alpha=up/hvkd
    alph=alpha
    PH=True
    nbands=2

    # print("Loading  ..........")
    with open(fulpath+'/dispersions/Edisp_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_plus_dos=np.load(f)
    with open(fulpath+'/dispersions/Edism_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_min_dos=np.load(f)

    hpl=Hamiltonian.Ham_BM_p(hvkd, alph, 1, lq, kappa, PH)
    hmin=Hamiltonian.Ham_BM_m(hvkd, alph, -1, lq, kappa, PH)

    Ndos=80
    ldos=MoireLattice.MoireTriangLattice(Ndos,theta,2)
    disp=Hamiltonian.Dispersion( ldos, nbands, hpl, hmin)
    [earr, dos, f2 ]=disp.DOS(Ene_valley_plus_dos,Ene_valley_min_dos)


    NN=2000
    mine=earr[1]
    maxe=earr[-2]
    mus=np.linspace(mine,maxe, NN)
    dosarr=f2(mus)
    de=mus[1]-mus[0]

    #FILLING FOR EACH CHEMICAL POTENTIAL
    ndens=[]
    for mu_ind in range(NN):
        N=np.trapz(dosarr[0:mu_ind])*de
        ndens.append(N)
            
    nn=np.array(ndens)
    nn=8*(nn/nn[-1])  - 4

    tdos.append(dosarr)
    thetass.append(theta)
    eners.append(mus)
    fils.append(nn)
    #
df=pd.concat(frames).sort_values(['theta', 'nu'])

thetass,tdos,eners,fils = zip(*sorted(zip(thetass,tdos,eners,fils)))
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3060610294342041  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999999964
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3243980407714844  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000039
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3005049228668213  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999787
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.29866814613342285  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999927
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3069472312927246  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999971
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31276893615722656  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000046
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.306628942489624  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999967
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3027210235595703  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999911
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.397921085357666  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000133
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.303800106048584  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000083
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.37105798721313477  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999931
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.38443803787231445  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999809
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3072948455810547  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999918
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31963324546813965  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000002
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31430888175964355  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999983
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3210408687591553  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000108
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31453490257263184  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.0
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3060719966888428  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999991
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3062582015991211  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999987
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3074469566345215  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999962
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3167421817779541  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999998
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30523014068603516  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000151
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32573890686035156  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000011
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3182101249694824  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000126
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3152909278869629  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000078

# %%
for i,t in enumerate(tdos):
    plot(eners[i],t, label=round(thetass[i]*180/np.pi,2))
legend(loc=1)
plt.show()


for i,t in enumerate(tdos):
    plot(fils[i],t, label=round(thetass[i]*180/np.pi,2))
legend(loc=1)

plt.show()

# %%
dataframeatgamma=df.loc[(df['kx']==0) & (df['ky']==0)] #since I have all the values of the bubble i need only to take one to check the effective c
tablenuthet=dataframeatgamma.pivot(index='nu', columns='theta', values='delt_cph')
cTrans=13600
cep=tablenuthet/cTrans
effectivec=np.sqrt(np.abs(1-cep**2))*np.heaviside(1-cep**2,0.0)

fig,ax = plt.subplots()
c=ax.pcolor(effectivec)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)
# plt.close()




fig,ax = plt.subplots()
c=ax.pcolor(tablenuthet)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)
# plt.close()
# Out:
# [Text(0, 0.5, '0.0'),
#  Text(0, 1.5, '0.21'),
#  Text(0, 2.5, '0.41'),
#  Text(0, 3.5, '0.62'),
#  Text(0, 4.5, '0.82'),
#  Text(0, 5.5, '1.03'),
#  Text(0, 6.5, '1.23'),
#  Text(0, 7.5, '1.44'),
#  Text(0, 8.5, '1.64'),
#  Text(0, 9.5, '1.85'),
#  Text(0, 10.5, '2.05'),
#  Text(0, 11.5, '2.26'),
#  Text(0, 12.5, '2.46'),
#  Text(0, 13.5, '2.67'),
#  Text(0, 14.5, '2.87'),
#  Text(0, 15.5, '3.08'),
#  Text(0, 16.5, '3.28'),
#  Text(0, 17.5, '3.49'),
#  Text(0, 18.5, '3.69'),
#  Text(0, 19.5, '3.9')]

# %%
kappa=0.75
path=pathy+'/data/thetasweep_kappa_'+str(kappa)+'_HR_N30'
subpaths=os.listdir(path)
subpaths=list(filter(lambda a: a != 'inforun', subpaths))

def getdatadir(fulpath,mode):
    data=[]
    for pa in fulpath:
        if ('data' in pa) and (mode in pa): data.append(pa)
    return data
        
thet=[]
renorm=[]
renorm2=[]
frames=[]
tdos=[]
thetass=[]
eners=[]
fils=[]
for i, pat in enumerate(subpaths):
    # print(pat)
    fulpath=path+'/'+pat
    subpaths2=os.listdir(fulpath)
    data= getdatadir(subpaths2, 'L')
    fullpath=fulpath+'/'+data[0]
    
    dff = pd.read_hdf(fullpath)
    frames.append(dff)

    

    Nsamp=100
    theta=dff['theta'][0]
    l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
    lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
    [q1,q2,q3]=l.q
    q=la.norm(q1)
    
    #JY params 
    hbvf = (3/(2*np.sqrt(3)))*2.7; # eV
    hvkd=hbvf*q
    up = 0.105; # eV
    u = kappa*up; # eV
    alpha=up/hvkd
    alph=alpha
    PH=True
    nbands=2

    # print("Loading  ..........")
    with open(fulpath+'/dispersions/Edisp_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_plus_dos=np.load(f)
    with open(fulpath+'/dispersions/Edism_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_min_dos=np.load(f)

    hpl=Hamiltonian.Ham_BM_p(hvkd, alph, 1, lq, kappa, PH)
    hmin=Hamiltonian.Ham_BM_m(hvkd, alph, -1, lq, kappa, PH)

    Ndos=80
    ldos=MoireLattice.MoireTriangLattice(Ndos,theta,2)
    disp=Hamiltonian.Dispersion( ldos, nbands, hpl, hmin)
    [earr, dos, f2 ]=disp.DOS(Ene_valley_plus_dos,Ene_valley_min_dos)


    NN=2000
    mine=earr[1]
    maxe=earr[-2]
    mus=np.linspace(mine,maxe, NN)
    dosarr=f2(mus)
    de=mus[1]-mus[0]

    #FILLING FOR EACH CHEMICAL POTENTIAL
    ndens=[]
    for mu_ind in range(NN):
        N=np.trapz(dosarr[0:mu_ind])*de
        ndens.append(N)
            
    nn=np.array(ndens)
    nn=8*(nn/nn[-1])  - 4

    tdos.append(dosarr)
    thetass.append(theta)
    eners.append(mus)
    fils.append(nn)
    #
df=pd.concat(frames).sort_values(['theta', 'nu'])

thetass,tdos,eners,fils = zip(*sorted(zip(thetass,tdos,eners,fils)))
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32065296173095703  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999983
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3166239261627197  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999987
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3165609836578369  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999927
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31658124923706055  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999809
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30583906173706055  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000108
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31723904609680176  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999967
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3126966953277588  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000011
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.34507179260253906  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999991
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32044291496276855  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.99999999999998
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30883026123046875  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999911
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31270670890808105  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999918
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3220341205596924  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999931
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3153977394104004  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000126
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3363349437713623  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000133
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32311201095581055  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000039
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3242321014404297  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.0
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3144357204437256  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000078
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31745314598083496  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000002
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32524919509887695  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000046
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3239438533782959  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999999964
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31830406188964844  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999971
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3179149627685547  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999962
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.4076671600341797  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999787
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.34355902671813965  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000151
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3409738540649414  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000083

# %%
dataframeatgamma=df.loc[(df['kx']==0) & (df['ky']==0)] #since I have all the values of the bubble i need only to take one to check the effective c
tablenuthet=dataframeatgamma.pivot(index='nu', columns='theta', values='delt_cph')
cLong=27400
cep=tablenuthet/cLong
effectivec=np.sqrt(np.abs(1-cep**2))*np.heaviside(1-cep**2,0.0)

fig,ax = plt.subplots()
c=ax.pcolor(effectivec)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)


fig,ax = plt.subplots()
c=ax.pcolor(tablenuthet)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)
# plt.close()
# Out:
# [Text(0, 0.5, '0.0'),
#  Text(0, 1.5, '0.21'),
#  Text(0, 2.5, '0.41'),
#  Text(0, 3.5, '0.62'),
#  Text(0, 4.5, '0.82'),
#  Text(0, 5.5, '1.03'),
#  Text(0, 6.5, '1.23'),
#  Text(0, 7.5, '1.44'),
#  Text(0, 8.5, '1.64'),
#  Text(0, 9.5, '1.85'),
#  Text(0, 10.5, '2.05'),
#  Text(0, 11.5, '2.26'),
#  Text(0, 12.5, '2.46'),
#  Text(0, 13.5, '2.67'),
#  Text(0, 14.5, '2.87'),
#  Text(0, 15.5, '3.08'),
#  Text(0, 16.5, '3.28'),
#  Text(0, 17.5, '3.49'),
#  Text(0, 18.5, '3.69'),
#  Text(0, 19.5, '3.9')]

# %% [markdown]
# ## For the twist angle 0.3

# %%
kappa=0.3
path=pathy+'/data/thetasweep_kappa_'+str(kappa)+'_T_HR_N30'
subpaths=os.listdir(path)
subpaths=list(filter(lambda a: a != 'inforun', subpaths))

def getdatadir(fulpath,mode):
    data=[]
    for pa in fulpath:
        if ('data' in pa) and (mode in pa): data.append(pa)
    return data
        
thet=[]
renorm=[]
renorm2=[]
frames=[]
tdos=[]
thetass=[]
eners=[]
fils=[]
for i, pat in enumerate(subpaths):
    # print(pat)
    fulpath=path+'/'+pat
    subpaths2=os.listdir(fulpath)
    data= getdatadir(subpaths2, 'T')
    fullpath=fulpath+'/'+data[0]
    
    dff = pd.read_hdf(fullpath)
    frames.append(dff)

    

    Nsamp=100
    theta=dff['theta'][0]
    l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
    lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
    [q1,q2,q3]=l.q
    q=la.norm(q1)
    
    #JY params 
    hbvf = (3/(2*np.sqrt(3)))*2.7; # eV
    hvkd=hbvf*q
    up = 0.105; # eV
    u = kappa*up; # eV
    alpha=up/hvkd
    alph=alpha
    PH=True
    nbands=2

    # print("Loading  ..........")
    with open(fulpath+'/dispersions/Edisp_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_plus_dos=np.load(f)
    with open(fulpath+'/dispersions/Edism_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_min_dos=np.load(f)

    hpl=Hamiltonian.Ham_BM_p(hvkd, alph, 1, lq, kappa, PH)
    hmin=Hamiltonian.Ham_BM_m(hvkd, alph, -1, lq, kappa, PH)

    Ndos=80
    ldos=MoireLattice.MoireTriangLattice(Ndos,theta,2)
    disp=Hamiltonian.Dispersion( ldos, nbands, hpl, hmin)
    [earr, dos, f2 ]=disp.DOS(Ene_valley_plus_dos,Ene_valley_min_dos)


    NN=2000
    mine=earr[1]
    maxe=earr[-2]
    mus=np.linspace(mine,maxe, NN)
    dosarr=f2(mus)
    de=mus[1]-mus[0]

    #FILLING FOR EACH CHEMICAL POTENTIAL
    ndens=[]
    for mu_ind in range(NN):
        N=np.trapz(dosarr[0:mu_ind])*de
        ndens.append(N)
            
    nn=np.array(ndens)
    nn=8*(nn/nn[-1])  - 4

    tdos.append(dosarr)
    thetass.append(theta)
    eners.append(mus)
    fils.append(nn)
    #
df=pd.concat(frames).sort_values(['theta', 'nu'])

thetass,tdos,eners,fils = zip(*sorted(zip(thetass,tdos,eners,fils)))
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.4323599338531494  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000021
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.33127808570861816  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000103
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3192460536956787  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3741147518157959  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000064
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3237600326538086  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000123
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3234901428222656  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000009
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3311610221862793  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000101
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31885290145874023  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000034
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3260610103607178  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.0000000000001
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3450651168823242  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.33515119552612305  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999864
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3460652828216553  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000008
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3202931880950928  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30437517166137695  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999815
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3047330379486084  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000107
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3028409481048584  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000062
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3061342239379883  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999974
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30913209915161133  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999964
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3084070682525635  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000057
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3259568214416504  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999888
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3142879009246826  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000075
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32744789123535156  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999999165
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.30127406120300293  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999982
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3041369915008545  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000071
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.33469319343566895  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999998765

# %%
for i,t in enumerate(tdos):
    plot(eners[i],t, label=round(thetass[i]*180/np.pi,2))
legend(loc=1)
plt.show()


for i,t in enumerate(tdos):
    plot(fils[i],t, label=round(thetass[i]*180/np.pi,2))
legend(loc=1)

plt.show()

# %%
dataframeatgamma=df.loc[(df['kx']==0) & (df['ky']==0)] #since I have all the values of the bubble i need only to take one to check the effective c
tablenuthet=dataframeatgamma.pivot(index='nu', columns='theta', values='delt_cph')
cTrans=13600
cep=tablenuthet/cTrans
effectivec=np.sqrt(np.abs(1-cep**2))*np.heaviside(1-cep**2,0.0)

fig,ax = plt.subplots()
c=ax.pcolor(effectivec)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)



fig,ax = plt.subplots()
c=ax.pcolor(tablenuthet)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)
# plt.close()
# Out:
# [Text(0, 0.5, '0.0'),
#  Text(0, 1.5, '0.21'),
#  Text(0, 2.5, '0.41'),
#  Text(0, 3.5, '0.62'),
#  Text(0, 4.5, '0.82'),
#  Text(0, 5.5, '1.03'),
#  Text(0, 6.5, '1.23'),
#  Text(0, 7.5, '1.44'),
#  Text(0, 8.5, '1.64'),
#  Text(0, 9.5, '1.85'),
#  Text(0, 10.5, '2.05'),
#  Text(0, 11.5, '2.26'),
#  Text(0, 12.5, '2.46'),
#  Text(0, 13.5, '2.67'),
#  Text(0, 14.5, '2.87'),
#  Text(0, 15.5, '3.08'),
#  Text(0, 16.5, '3.28'),
#  Text(0, 17.5, '3.49'),
#  Text(0, 18.5, '3.69'),
#  Text(0, 19.5, '3.9')]

# %%
kappa=0.3
path=pathy+'/data/thetasweep_kappa_'+str(kappa)+'_HR_N30'
subpaths=os.listdir(path)
subpaths=list(filter(lambda a: a != 'inforun', subpaths))

def getdatadir(fulpath,mode):
    data=[]
    for pa in fulpath:
        if ('data' in pa) and (mode in pa): data.append(pa)
    return data
        
thet=[]
renorm=[]
renorm2=[]
frames=[]
tdos=[]
thetass=[]
eners=[]
fils=[]
for i, pat in enumerate(subpaths):
    # print(pat)
    fulpath=path+'/'+pat
    subpaths2=os.listdir(fulpath)
    data= getdatadir(subpaths2, 'L')
    fullpath=fulpath+'/'+data[0]
    
    dff = pd.read_hdf(fullpath)
    frames.append(dff)

    

    Nsamp=100
    theta=dff['theta'][0]
    l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
    lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
    [q1,q2,q3]=l.q
    q=la.norm(q1)
    
    #JY params 
    hbvf = (3/(2*np.sqrt(3)))*2.7; # eV
    hvkd=hbvf*q
    up = 0.105; # eV
    u = kappa*up; # eV
    alpha=up/hvkd
    alph=alpha
    PH=True
    nbands=2

    # print("Loading  ..........")
    with open(fulpath+'/dispersions/Edisp_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_plus_dos=np.load(f)
    with open(fulpath+'/dispersions/Edism_'+str(lq.Npoints)+'_theta_'+str(lq.theta)+'.npy', 'rb') as f:
        Ene_valley_min_dos=np.load(f)

    hpl=Hamiltonian.Ham_BM_p(hvkd, alph, 1, lq, kappa, PH)
    hmin=Hamiltonian.Ham_BM_m(hvkd, alph, -1, lq, kappa, PH)

    Ndos=80
    ldos=MoireLattice.MoireTriangLattice(Ndos,theta,2)
    disp=Hamiltonian.Dispersion( ldos, nbands, hpl, hmin)
    [earr, dos, f2 ]=disp.DOS(Ene_valley_plus_dos,Ene_valley_min_dos)


    NN=2000
    mine=earr[1]
    maxe=earr[-2]
    mus=np.linspace(mine,maxe, NN)
    dosarr=f2(mus)
    de=mus[1]-mus[0]

    #FILLING FOR EACH CHEMICAL POTENTIAL
    ndens=[]
    for mu_ind in range(NN):
        N=np.trapz(dosarr[0:mu_ind])*de
        ndens.append(N)
            
    nn=np.array(ndens)
    nn=8*(nn/nn[-1])  - 4

    tdos.append(dosarr)
    thetass.append(theta)
    eners.append(mus)
    fils.append(nn)
    #
df=pd.concat(frames).sort_values(['theta', 'nu'])

thetass,tdos,eners,fils = zip(*sorted(zip(thetass,tdos,eners,fils)))
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31409215927124023  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000009
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3286468982696533  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999815
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.36419081687927246  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000057
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32271599769592285  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999864
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3096299171447754  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.0000000000001
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32126307487487793  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000071
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3120739459991455  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000021
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3190920352935791  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000123
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32475709915161133  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999998765
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3137080669403076  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.9999999999999165
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32636213302612305  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999982
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.38990211486816406  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000075
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.395733118057251  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000103
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32582783699035645  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999888
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.31566405296325684  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000034
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32315874099731445  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000107
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.33713769912719727  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.00000000000008
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.32343339920043945  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999974
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3556809425354004  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3499867916107178  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 7.999999999999964
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3738267421722412  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000062
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3303501605987549  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000101
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3358321189880371  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3193941116333008  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000064
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.3163590431213379  s
# number of bands in density of states calculation, 2
# sum of the hist, normed? 8.000000000000032

# %%
dataframeatgamma=df.loc[(df['kx']==0) & (df['ky']==0)] #since I have all the values of the bubble i need only to take one to check the effective c
tablenuthet=dataframeatgamma.pivot(index='nu', columns='theta', values='delt_cph')
cLong=27400
cep=tablenuthet/cLong
effectivec=np.sqrt(np.abs(1-cep**2))*np.heaviside(1-cep**2,0.0)

fig,ax = plt.subplots()
c=ax.pcolor(effectivec)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)


fig,ax = plt.subplots()
c=ax.pcolor(tablenuthet)
fig.colorbar(c, ax=ax)


ax.set_xticks(np.arange(tablenuthet.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(tablenuthet.shape[0]) + 0.5, minor=False)

# # Rotate the xlabels. Set both x and y labels to headers[1:]
thets=(dataframeatgamma['theta'].unique()*180/np.pi).round(decimals=2)
nus=(dataframeatgamma['nu'].unique()).round(decimals=2)
ax.set_xticklabels(thets,rotation=90)
ax.set_yticklabels(nus)
# plt.close()
# Out:
# [Text(0, 0.5, '0.0'),
#  Text(0, 1.5, '0.21'),
#  Text(0, 2.5, '0.41'),
#  Text(0, 3.5, '0.62'),
#  Text(0, 4.5, '0.82'),
#  Text(0, 5.5, '1.03'),
#  Text(0, 6.5, '1.23'),
#  Text(0, 7.5, '1.44'),
#  Text(0, 8.5, '1.64'),
#  Text(0, 9.5, '1.85'),
#  Text(0, 10.5, '2.05'),
#  Text(0, 11.5, '2.26'),
#  Text(0, 12.5, '2.46'),
#  Text(0, 13.5, '2.67'),
#  Text(0, 14.5, '2.87'),
#  Text(0, 15.5, '3.08'),
#  Text(0, 16.5, '3.28'),
#  Text(0, 17.5, '3.49'),
#  Text(0, 18.5, '3.69'),
#  Text(0, 19.5, '3.9')]

# %% [markdown]
# # For kappa

# %%
path='/home/jfm343/Documents/Moire_phonon/BM_bandstructure/data/kappasweep_theta_1.05_beta_4ev_N30_2022-01-20-09-58-20'
subpaths=os.listdir(path)
subpaths=list(filter(lambda a: a != 'inforun', subpaths))

def getdatadir(fulpath,mode):
    data=[]
    for pa in fulpath:
        if ('data' in pa) and (mode in pa): data.append(pa)
    return data
        

for i, pat in enumerate(subpaths):
    fulpath=path+'/'+pat
    subpaths2=os.listdir(fulpath)
    data= getdatadir(subpaths2, 'T')
    fullpath=fulpath+'/'+data[0]
    
    df = pd.read_hdf(fullpath)
    
    fillings=df['nu']
    cep=df['delt_cph']/21400
    cep2=np.sqrt(1-cep**2)
    plt.scatter(fillings, cep, label=str(df['kappa'][0]))
    plt.plot(fillings, cep, c='k', ls='--')
    plt.legend()
    plt.xlabel(r"$\nu$")
    plt.ylabel(r"$\alpha/ c_L$")
    # plt.savefig("velocities_V_filling_"+self.name+"_"+str(Nsamp)+"_theta_"+str(theta)+".png")

# %%
import Hamiltonian
import MoireLattice
from scipy import linalg as la

#Lattice parameters 
#lattices with different normalizations
modulation_thet=1
Nsamp=10
theta=modulation_thet*1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=0
print(f"taking {umkl} umklapps")
VV=lq.boundary()

print(q, 2*np.sin(theta/2)*np.pi*(4/3))
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.005800485610961914  s
# 91 numer of sampling lattice points
# taking 0 umklapps
# 0.07676251561000431 0.0767625156100043

# %%
theta=np.linspace(0.9,1.2,31)
bw03=loadtxt(pathy+'/data/bws_test/bw03.dat')
bw075=loadtxt(pathy+'/data/bws_test/bw075.dat')
scatter(theta, bw03)
scatter(theta, bw075)

# %%
f = open(pathy+'/data/bws_test/bw03.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
    
scatter(thetaas,bws)
f = open(pathy+'/data/bws_test/bw075.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
scatter(thetaas,bws)
# Out:
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721
#
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721

# %%
f = open(pathy+'/data/bws_test/bw03.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
    
scatter(thetaas,bws)
f = open(pathy+'/data/bws_test/bw075.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
scatter(thetaas,bws)
# Out:
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721
#
# 0.91 0.02742032974804828
#
# 0.92 0.029928191820134963
#
# 0.93 0.028589100562741047
#
# 0.94 0.026733068266046173
#
# 0.95 0.024825809831399082
#
# 0.96 0.022869334550215812
#
# 0.97 0.020865579684169744
#
# 0.98 0.018816410634258318
#
# 0.99 0.016723621569897547
#
# 0.9 0.02494695974009223
#
# 1.01 0.01241401027608267
#
# 1.02 0.01020043078261224
#
# 1.03 0.007949720065848253
#
# 1.04 0.0056633365500721716
#
# 1.05 0.0033426769845892714
#
# 1.06 0.0009890785268491294
#
# 1.07 0.0013961791294456523
#
# 1.08 0.0038118716050895836
#
# 1.09 0.006256827684803911
#
# 1.0 0.014588936437283295
#
# 1.11 0.011230098829931829
#
# 1.12 0.013756318216675827
#
# 1.13 0.01630760576116779
#
# 1.14 0.01888302474808859
#
# 1.15 0.021481679419788277
#
# 1.16 0.02410271313105219
#
# 1.17 0.026745306568822742
#
# 1.18 0.02940867603829984
#
# 1.19 0.03209207181609805
#
# 1.1 0.008729927181679087
#
# 1.2 0.034794776570457375

# %%
f = open(pathy+'/data/bws_test/bw03_2.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
    
scatter(thetaas,bws,label=r'$\kappa=0.3$')
f = open(pathy+'/data/bws_test/bw075_2.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
scatter(thetaas,bws, label=r'$\kappa=0.75$')
xlabel(r'$\theta$')
ylabel(r'$W$ [eV]')
legend()
# Out:
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721
#
# 0.91 0.02742032974804828
#
# 0.92 0.029928191820134963
#
# 0.93 0.028589100562741047
#
# 0.94 0.026733068266046173
#
# 0.95 0.024825809831399082
#
# 0.96 0.022869334550215812
#
# 0.97 0.020865579684169744
#
# 0.98 0.018816410634258318
#
# 0.99 0.016723621569897547
#
# 0.9 0.02494695974009223
#
# 1.01 0.01241401027608267
#
# 1.02 0.01020043078261224
#
# 1.03 0.007949720065848253
#
# 1.04 0.0056633365500721716
#
# 1.05 0.0033426769845892714
#
# 1.06 0.0009890785268491294
#
# 1.07 0.0013961791294456523
#
# 1.08 0.0038118716050895836
#
# 1.09 0.006256827684803911
#
# 1.0 0.014588936437283295
#
# 1.11 0.011230098829931829
#
# 1.12 0.013756318216675827
#
# 1.13 0.01630760576116779
#
# 1.14 0.01888302474808859
#
# 1.15 0.021481679419788277
#
# 1.16 0.02410271313105219
#
# 1.17 0.026745306568822742
#
# 1.18 0.02940867603829984
#
# 1.19 0.03209207181609805
#
# 1.1 0.008729927181679087
#
# 1.2 0.034794776570457375

# %%
f = open(pathy+'/data/bws_test/bw03_kp.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
    
scatter(thetaas,bws,label=r'$\kappa=0.3$')
f = open(pathy+'/data/bws_test/bw075_kp.dat', "r")
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))
scatter(thetaas,bws, label=r'$\kappa=0.75$')
xlabel(r'$\theta$')
ylabel(r'$W$ [eV]')
legend()
# Out:
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721
#
# 0.91 0.02742032974804828
#
# 0.92 0.029928191820134963
#
# 0.93 0.028589100562741047
#
# 0.94 0.026733068266046173
#
# 0.95 0.024825809831399082
#
# 0.96 0.022869334550215812
#
# 0.97 0.020865579684169744
#
# 0.98 0.018816410634258318
#
# 0.99 0.016723621569897547
#
# 0.9 0.02494695974009223
#
# 1.01 0.01241401027608267
#
# 1.02 0.01020043078261224
#
# 1.03 0.007949720065848253
#
# 1.04 0.0056633365500721716
#
# 1.05 0.0033426769845892714
#
# 1.06 0.0009890785268491294
#
# 1.07 0.0013961791294456523
#
# 1.08 0.0038118716050895836
#
# 1.09 0.006256827684803911
#
# 1.0 0.014588936437283295
#
# 1.11 0.011230098829931829
#
# 1.12 0.013756318216675827
#
# 1.13 0.01630760576116779
#
# 1.14 0.01888302474808859
#
# 1.15 0.021481679419788277
#
# 1.16 0.02410271313105219
#
# 1.17 0.026745306568822742
#
# 1.18 0.02940867603829984
#
# 1.19 0.03209207181609805
#
# 1.1 0.008729927181679087
#
# 1.2 0.034794776570457375

# %%
#JY params 

hbvf = (3/(2*np.sqrt(3)))*2.7; # eV
up = 0.105; # eV
Kd=4*np.pi/3

f = open(pathy+'/data/bws_test/bw03_kp.dat', "r")
kappa=0.3
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))

tht=np.array(thetaas)*np.pi/180
q=2*np.sin(tht/2)*Kd
hvkd=hbvf*q
alpha=up/hvkd
alph=alpha   
scatter(alph,bws,label=r'$\kappa=0.3$')


f = open(pathy+'/data/bws_test/bw075_2band_kp.dat', "r")
kappa=0.75
thetaas=[]
bws=[]
for a in f.readlines():
    b=a.split('\t') 
    print(b[0].split("_")[-1][:-15], b[1])
    thetaas.append(float(b[0].split("_")[-1][:-15]))
    bws.append(float(b[1]))


tht=np.array(thetaas)*np.pi/180
q=2*np.sin(tht/2)*Kd
hvkd=hbvf*q
alpha=up/hvkd
alph=alpha   

scatter(alph,bws, label=r'$\kappa=0.75$')
xlabel(r'$\theta$')
ylabel(r'$W$ [eV]')
legend()
# Out:
# 0.91 0.033643931262116095
#
# 0.92 0.03145758337276082
#
# 0.93 0.029236171154953108
#
# 0.94 0.026980980000201455
#
# 0.95 0.02469324462263112
#
# 0.96 0.02237415064418439
#
# 0.97 0.020024836213661294
#
# 0.98 0.017646393643587048
#
# 0.99 0.015239871051386557
#
# 0.9 0.0357938772215257
#
# 1.01 0.010346567083396738
#
# 1.02 0.007861675584589542
#
# 1.03 0.005352486974308776
#
# 1.04 0.00281985247086812
#
# 1.05 0.0002645885219768042
#
# 1.06 0.0023125217494067243
#
# 1.07 0.004910727143794225
#
# 1.08 0.007529307029984963
#
# 1.09 0.010167570036903297
#
# 1.0 0.01280627399355594
#
# 1.11 0.015500518712672166
#
# 1.12 0.01819395683114167
#
# 1.13 0.02090458068435653
#
# 1.14 0.02363182723598342
#
# 1.15 0.02637515584880859
#
# 1.16 0.02913404730000814
#
# 1.17 0.03190800283898172
#
# 1.18 0.03469654328645112
#
# 1.19 0.0374992081734728
#
# 1.1 0.012824852792918218
#
# 1.2 0.04031555491896721
#
# 0.91 0.02742032974804828
#
# 0.92 0.029928191820134963
#
# 0.93 0.028589100562741047
#
# 0.94 0.026733068266046173
#
# 0.95 0.024825809831399082
#
# 0.96 0.022869334550215812
#
# 0.97 0.020865579684169744
#
# 0.98 0.018816410634258318
#
# 0.99 0.016723621569897547
#
# 0.9 0.02494695974009223
#
# 1.01 0.01241401027608267
#
# 1.02 0.01020043078261224
#
# 1.03 0.007949720065848253
#
# 1.04 0.0056633365500721716
#
# 1.05 0.0033426769845892714
#
# 1.06 0.0009890785268491294
#
# 1.07 0.0013961791294456523
#
# 1.08 0.0038118716050895836
#
# 1.09 0.006256827684803911
#
# 1.0 0.014588936437283295
#
# 1.11 0.011230098829931829
#
# 1.12 0.013756318216675827
#
# 1.13 0.01630760576116779
#
# 1.14 0.01888302474808859
#
# 1.15 0.021481679419788277
#
# 1.16 0.02410271313105219
#
# 1.17 0.026745306568822742
#
# 1.18 0.02940867603829984
#
# 1.19 0.03209207181609805
#
# 1.1 0.008729927181679087
#
# 1.2 0.034794776570457375
