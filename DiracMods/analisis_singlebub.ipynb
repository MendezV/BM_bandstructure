# %%
# %pylab inline
import numpy as np
import pandas as pd
import os
import Hamiltonian
import Lattice
from scipy import linalg as la
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/DiracMods/singlebubs/'
path=path+'data10ee.h5'

df = pd.read_hdf(path)

# %%
Nsamp=10
theta=1.05*np.pi/180  # magic angle 
l=Lattice.TriangLattice(Nsamp,0) 
[KX,KY]=l.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
umkl=1
print(f"taking {umkl} umklapps")
VV=l.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
# A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=2#/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.0041239261627197266  s
# 109 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/DiracMods/singlebubs/'
# path=path+'data60ee.h5'
path=path+'data60graphee.h5'
df = pd.read_hdf(path)

# %%
Nsamp=30
theta=1.05*np.pi/180  # magic angle 
l=Lattice.TriangLattice(Nsamp,0) 
[KX,KY]=l.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
umkl=1
print(f"taking {umkl} umklapps")
VV=l.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
# A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=2 #for spins 1#/A1mbz
Vol=l.VolMBZ

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)
hbvf = 2.1354; # eV
fac=(4*np.pi*np.pi)*(1/4)/(hbvf)  #comparing my calculation to the one in Dynamical Polarization of graphene at finite doping, there is an extra factor of 4*pi^2 and 
plot(df_one_temp['ky'],fac*np.abs(df_one_temp['ky']))
# ylim([0,4])
plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
plot(df_one_temp['kx'],fac*np.abs(df_one_temp['kx']))
# ylim([0,4])
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.034052371978759766  s
# 931 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/DiracMods/singlebubs/'
path=path+'datanoFF60ee.h5'

df = pd.read_hdf(path)

# %%
Nsamp=30
theta=1.05*np.pi/180  # magic angle 
l=Lattice.TriangLattice(Nsamp,0) 
[KX,KY]=l.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
umkl=1
print(f"taking {umkl} umklapps")
VV=l.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
# A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1#/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.03522014617919922  s
# 931 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/DiracMods/singlebubs/'
path=path+'data60diree.h5'

df = pd.read_hdf(path)

# %%
Nsamp=30
theta=1.05*np.pi/180  # magic angle 
l=Lattice.TriangLattice(Nsamp,0) 
[KX,KY]=l.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
umkl=1
print(f"taking {umkl} umklapps")
VV=l.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
# A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
g=2 #for spins 1#/A1mbz
Vol=l.VolMBZ

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*g)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*g)
hbvf = 2.1354; # eV
fac=(4*np.pi*np.pi)*(1/4)/(hbvf)
plot(df_one_temp['ky'],fac*np.abs(df_one_temp['ky']))
# ylim([0,4])
plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*g)
plot(df_one_temp['kx'],fac*np.abs(df_one_temp['kx']))
# ylim([0,4])
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.04049563407897949  s
# 931 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
