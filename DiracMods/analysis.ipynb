# %%
# %pylab inline
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jfm343/anaconda3/lib/python3.8/site-packages/IPython/core/magics/pylab.py:159: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
integ_dir1=0
with open("bubble_data_10_nu_0.0ee.npy", 'rb') as f:
            integ_dir1=np.load(f)
kx_dir1=0
with open("bubble_data_kx_10_nu_0.0ee.npy", 'rb') as f:
            kx_dir1=np.load(f)

ky_dir1=0
with open("bubble_data_ky_10_nu_0.0ee.npy", 'rb') as f:
            ky_dir1=np.load(f)

# %%
scatter(kx_dir1,ky_dir1, c=integ_dir1)
colorbar()
show()


ind0=where(ky_dir1==0)
plot(kx_dir1[ind0], integ_dir1[ind0])
hbvf = 2.1354; # eV

hhbar=6.582119569e-16 
hbarvf=hhbar*1e+6  #ev m
hbarc=0.1973269804*1e-6 #ev*m
alpha=137.0359895 #fine structure constant
a_graphene=2.458*(1e-10) #in meters
e_el=1.6021766*(10**(-19))  #in joule/ev
eps= 8.8541878128*1e-12
abohr=5.29*1e-11
ee2=(e_el)**2 /(4*np.pi*eps)
print(0.5*ee2/e_el)
e2=0.5*ee2/e_el #ev m
hbvf=0.003404*0.1973269804*1e-6 /a_graphene #ev*m
print(e2/hbarvf)
coef=a_graphene /(hbarvf)

plot(kx_dir1[ind0]*coef)
# Out:
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# 7.199822586424456e-10
# 1.093845608690196
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
integ_dir1=0
with open("bubble_data_20_nu_2.0526315789473686ee.npy", 'rb') as f:
            integ_dir1=np.load(f)
kx_dir1=0
with open("bubble_data_kx_20_nu_0.0ee.npy", 'rb') as f:
            kx_dir1=np.load(f)

ky_dir1=0
with open("bubble_data_ky_20_nu_0.0ee.npy", 'rb') as f:
            ky_dir1=np.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-ad01ab6e1714> in <module>
#       1 integ_dir1=0
# ----> 2 with open("bubble_data_20_nu_2.0526315789473686ee.npy", 'rb') as f:
#       3             integ_dir1=np.load(f)
#       4 kx_dir1=0
#       5 with open("bubble_data_kx_20_nu_0.0ee.npy", 'rb') as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bubble_data_20_nu_2.0526315789473686ee.npy'

# %%
scatter(kx_dir1,ky_dir1, c=integ_dir1)
colorbar()
show()


ind0=where(ky_dir1==0)
plot(kx_dir1[ind0], integ_dir1[ind0])
# Out:
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
integ_moi=0
with open("bubble_data_lh21_nu_0.0ee.npy", 'rb') as f:
            integ_moi=np.load(f)
integ_moi2=0
with open("bubble_data_21_nu_0.0ee.npy", 'rb') as f:
            integ_moi2=np.load(f)
integ_moi3=0
with open("bubble_data_FG21_nu_0.0ee.npy", 'rb') as f:
            integ_moi3=np.load(f)

kx_moi=0
with open("bubble_data_kx_21_nu_0.0ee.npy", 'rb') as f:
            kx_moi=np.load(f)

ky_moi=0
with open("bubble_data_ky_21_nu_0.0ee.npy", 'rb') as f:
            ky_moi=np.load(f)

# %%
scatter(kx_moi,ky_moi, c=integ_moi)
colorbar()
show()
scatter(kx_moi,ky_moi, c=integ_moi2)
colorbar()
show()
scatter(kx_moi,ky_moi, c=integ_moi3)
colorbar()
show()
scatter(kx_moi,ky_moi, c=abs(integ_moi-integ_moi2))
colorbar()
show()
scatter(kx_moi,ky_moi, c=abs(integ_moi3-integ_moi))
colorbar()
show()
ind0=where(ky_moi==0)
plot(kx_moi[ind0], integ_moi[ind0])
# Out:
# /home/juan/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %% [markdown]
# ## For the sound velocity

# %%
integ_dir1=0
with open("velocities_V_filling__mode_L_symmetry_a_alpha_0_beta_4_umklp_0_theta_0.01832595714594046.npy", 'rb') as f:
            integ_dir1=np.load(f)

# %%
plot(1-integ_dir1**2, 'o')
