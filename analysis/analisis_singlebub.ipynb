# %%
# %pylab inline
import numpy as np
import pandas as pd
import os
import Hamiltonian
import MoireLattice
from scipy import linalg as la
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'

df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.012274980545043945  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
Nsamp=50
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
x=KX#df_prime['kx']
y=KY#df_prime['ky']
f=10*(x**2 +y**2)
scatter(x,y, c=f)
colorbar()
eps=np.mean(abs(np.diff(f)))
aa=np.where(np.abs(f-6)<eps)[0]
print(aa, eps)
scatter(x[aa],y[aa], c='r', s=3)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.09459853172302246  s
# [ 101  102  103  104  105  106  107  108  109  110  131  132  133  143
#   144  145  162  163  164  179  180  181  195  196  216  217  229  230
#   253  254  265  291  301  302  329  330  339  369  377  378  409  410
#   417  451  458  493  500  536  543  580  587  625  632  671  678  718
#   725  766  773  815  823  864  873  915  924  967  977 1019 1030 1073
#  1084 1128 1140 1183 1196 1240 1253 1296 1308 1352 1363 1406 1417 1459
#  1469 1512 1521 1563 1572 1613 1621 1663 1670 1711 1718 1758 1765 1804
#  1811 1849 1856 1893 1900 1936 1943 1978 1985 2019 2026 2027 2058 2059
#  2067 2097 2106 2107 2134 2135 2145 2171 2182 2183 2206 2207 2219 2220
#  2240 2241 2255 2256 2257 2272 2273 2274 2291 2292 2293 2303 2304 2305
#  2326 2327 2328 2329 2330 2331 2332 2333 2334 2335] 0.2743079990616938

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'

df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009453058242797852  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'datano_FF30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'data_no_FF_30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)
df
# Out:
#               bub        kx        ky   nu      delt_cph   res_fit     theta  \
# 0    6.723073e+17 -0.866025 -0.500000  0.0  94709.338478  0.649871  0.018326
# 1    7.389304e+17 -0.866025 -0.441176  0.0  94709.338478  0.649871  0.018326
# 2    4.977359e+17 -0.866025 -0.382353  0.0  94709.338478  0.649871  0.018326
# 3    4.449080e+17 -0.866025 -0.323529  0.0  94709.338478  0.649871  0.018326
# 4    3.427803e+17 -0.866025 -0.264706  0.0  94709.338478  0.649871  0.018326
# ..            ...       ...       ...  ...           ...       ...       ...
# 914  3.347583e+17  0.866025  0.264706  0.0  94709.338478  0.649871  0.018326
# 915  4.330800e+17  0.866025  0.323529  0.0  94709.338478  0.649871  0.018326
# 916  4.787073e+17  0.866025  0.382353  0.0  94709.338478  0.649871  0.018326
# 917  7.392924e+17  0.866025  0.441176  0.0  94709.338478  0.649871  0.018326
# 918  6.726485e+17  0.866025  0.500000  0.0  94709.338478  0.649871  0.018326
#
#      kappa
# 0     0.75
# 1     0.75
# 2     0.75
# 3     0.75
# 4     0.75
# ..     ...
# 914   0.75
# 915   0.75
# 916   0.75
# 917   0.75
# 918   0.75
#
# [919 rows x 8 columns]

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.colorbar()
plt.plot(VV[:,0],VV[:,1], c='r')


plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009144306182861328  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
path=pathy+'/Mods/data10_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_3_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

print(df_prime['kx'].loc[argmax(df_prime['bub'])],df_prime['ky'].loc[argmax(df_prime['bub'])])
print(lq.GMvec)
pos=lq.GMvec[0]+2*lq.GMvec[1]

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz, s=10)
colorbar()
plt.scatter(df_prime['kx'].loc[argmax(df_prime['bub'])],df_prime['ky'].loc[argmax(df_prime['bub'])], c='b', s=10)
plt.scatter(pos[0],pos[1], c='r', s=10)
plt.plot(VV[:,0],VV[:,1], c='r')
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.016591548919677734  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# 0.8660254037844392 0.5000000000000003
# [array([0.8660254, 1.5      ]), array([-1.73205081,  0.        ])]

# %%
path=pathy+'/Mods/data10_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_3_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()

a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

print(df_prime['kx'].loc[argmax(df_prime['bub'])],df_prime['ky'].loc[argmax(df_prime['bub'])])
print(lq.GMvec)
pos=lq.GMvec[0]

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz,s=10)
colorbar()
plt.scatter(df_prime['kx'].loc[argmax(df_prime['bub'])],df_prime['ky'].loc[argmax(df_prime['bub'])], c='b', s=10)
plt.scatter(pos[0],pos[1], c='r', s=10)
plt.plot(VV[:,0],VV[:,1], c='r')
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.021957874298095703  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# -2.598076211353319 1.5
# [array([0.8660254, 1.5      ]), array([-1.73205081,  0.        ])]

# %%
path=pathy+'/Mods/data15_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()

a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.012227058410644531  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
path=pathy+'/Mods/data10_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_3_kappa_0.3_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=10
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()

a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.007335186004638672  s
# 91 numer of sampling lattice points
# taking 1 umklapps

# %%
path=pathy+'/Mods/data10_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_3_kappa_0.3_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=10
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()

a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.00794219970703125  s
# 91 numer of sampling lattice points
# taking 1 umklapps

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathMAC
path=pathy+'/Mods/singlebubs/'
# path=path+'data15_mode_L_symmetry_a_alpha_0.5_beta_1.0_umklp_1_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'data30_mode_T_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'

df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.013791084289550781  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %% [markdown]
# # comparison between ieps and der

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'

path=path+'ieps_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'ieps_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.011337041854858398  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'


path=path+'ieps_noFF_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'ieps_noFF_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009613752365112305  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'

path=path+'ieps_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
# path=path+'ieps_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'

df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009803295135498047  s
# 217 numer of sampling lattice points
# taking 1 umklapps
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/jfm343/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'

# path=path+'delt_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'delt_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.013485193252563477  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'

# path=path+'delt_noFF_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'delt_noFF_data30_mode_L_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'
0.01832595714594046

df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.015331745147705078  s
# 217 numer of sampling lattice points
# taking 1 umklapps

# %%
pathMAC="/Users/jfmv/Documents/Proyectos/Moire-Phonon_QMC/BM_bandstructure"
pathchow='/home/jfm343/Documents/Moire_phonon/BM_bandstructure'
pathpc='/home/juan/Documents/Projects/BM_bandstructure'
pathy=pathchow
path=pathy+'/Mods/singlebubs/'

# path=path+'delt_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.018500490071139894.h5'
path=path+'delt_data30_mode_dens_symmetry_a_alpha_0.0_beta_1.0_umklp_0_kappa_0.75_theta_0.01832595714594046.h5'


df = pd.read_hdf(path)

# %%
Nsamp=15
theta=1.05*np.pi/180  # magic angle 
l=MoireLattice.MoireTriangLattice(Nsamp,theta,0) 
lq=MoireLattice.MoireTriangLattice(Nsamp,theta,2) #this one 
[KX,KY]=lq.Generate_lattice()
Npoi=np.size(KX); print(Npoi, "numer of sampling lattice points")
[q1,q2,q3]=l.q
q=la.norm(q1)
umkl=1
print(f"taking {umkl} umklapps")
VV=lq.boundary()


a_graphene=2.458*(1e-10) #in meters this is the lattice constant NOT the carbon-carbon distance
A1mbz=lq.VolMBZ*((q**2)/(a_graphene**2))
ev_Ambz=1/A1mbz

df_prime=df.loc[df['nu']==0]
scatter(df_prime['kx'],df_prime['ky'], c=df_prime['bub']*ev_Ambz)
plt.plot(VV[:,0],VV[:,1], c='r')
colorbar()

plt.show()


df_one_temp=df.loc[(df['nu'] == 0.0) & (df['kx'] == 0.0)]
scatter(df_one_temp['ky'],df_one_temp['bub']*ev_Ambz)

plt.show()

df_one_temp=df.loc[(df['nu'] == 0.0) & (df['ky'] == 0.0)]
plt.scatter(df_one_temp['kx'],df_one_temp['bub']*ev_Ambz)
# Out:
# starting sampling in reciprocal space....
# finished sampling in reciprocal space....t= 0.009842157363891602  s
# 217 numer of sampling lattice points
# taking 1 umklapps
